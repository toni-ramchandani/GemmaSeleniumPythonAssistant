# %%
import keras_nlp
import keras
import os
import pandas as pd
# Out:
# 2024-04-08 16:38:30.867754: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-08 16:38:30.867923: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-08 16:38:31.020325: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
os.environ["KERAS_BACKEND"] = "jax"
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"]="1.00"

# %%
gemma_lm = keras_nlp.models.GemmaCausalLM.from_preset("gemma_2b_en")
# Out:
# Attaching 'config.json' from model 'keras/gemma/keras/gemma_2b_en/2' to your Kaggle notebook...
# Attaching 'config.json' from model 'keras/gemma/keras/gemma_2b_en/2' to your Kaggle notebook...
# Attaching 'model.weights.h5' from model 'keras/gemma/keras/gemma_2b_en/2' to your Kaggle notebook...
# Attaching 'tokenizer.json' from model 'keras/gemma/keras/gemma_2b_en/2' to your Kaggle notebook...
# Attaching 'assets/tokenizer/vocabulary.spm' from model 'keras/gemma/keras/gemma_2b_en/2' to your Kaggle notebook...
# normalizer.cc(51) LOG(INFO) precompiled_charsmap is empty. use identity normalization.

# %%
model.summary()

# %%
def get_prompt(query:str)->str:
    template = "Instruction:\n{instruction}\n\nResponse:\n{response}"
    prompt = template.format(
        instruction=query,
        response="",
    )
    return prompt

# %%
sampler = keras_nlp.samplers.TopKSampler(k=5, seed=2)
gemma_lm.compile(sampler=sampler)

# %%
prompt = get_prompt("What are latest updates of seleniun in Python?")
print(gemma_lm.generate(prompt, max_length=512))
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1712594682.540987      33 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2024-04-08 16:44:42.594987: E external/local_xla/xla/stream_executor/stream_executor_internal.h:177] SetPriority unimplemented for this stream.
# Instruction:
# What are latest updates of seleniun in Python?
#
# Response:
# Selenium WebDriver is a Java-based library that allows you to automate testing of web applications. It is a powerful tool for automating web applications and has become the de-facto standard for web application automation.
#
# In Python, selenium-webdriver module is used to automate web applications in Python. It provides a rich set of methods for automating web applications and supports multiple programming languages including Python, Java, Ruby, C#, PHP, Perl, and Javascript.
#
# The latest update to selenium-webdriver in Python includes the introduction of a new feature called “WebDriverWait”. This new feature allows you to wait for an element to load or become visible on a webpage before proceeding with further automation. It also supports multiple timeouts, allowing you to set different timeouts for different elements on a web page.
#
# Selenium-webdriver also provides support for a number of new features, including the ability to take screenshots of a web page during automation, and the ability to interact with the DOM of a web page through the use of JavaScript. It also provides support for a number of new capabilities, including the ability to interact with web services, and the ability to use the browser’s DOM directly.
#
# Selenium-webdriver also provides support for a number of new features, including the ability to interact with web services, and the ability to use the browser’s DOM directly. It also provides support for a number of new capabilities, including the ability to interact with web services, and the ability to use the browser’s DOM directly.
#
# In summary, the latest update to the selenium-webdriver in Python includes a number of new features and capabilities, as well as a number of new APIs.
#
# <h2><strong>How to automate web application using selenium in python?</strong></h2>
#
# Automation of web applications is a process in which a computer program is used to perform tasks that would otherwise be performed manually. Selenium is a popular open source automation tool that allows you to automate web applications using Python, Java, Ruby, and other programming languages.
#
# To automate a web application in Python using selenium, you will need to install the selenium package and the required dependencies. Once the dependencies are installed, you can start the automation process by creating a WebDriver object.
#
# The WebDriver object can be used to interact with the web application and perform various tasks, such as opening a browser, navigating to a URL, and clicking on buttons and links. You can also set up automation tests using the WebDriver object, which allows
